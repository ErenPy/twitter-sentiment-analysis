# %%
import csv
import string
import time
import re
import pandas as pd

# %%
def UrlRemover(tweet) :
    newTweet = []
    for words in tweet :
        isUrl = False
        patternCount = 0
        for letters in words :
            if letters == 'c' or letters == 'o' or letters == 'm' or letters == '.' :
                patternCount += 1
                if patternCount == 4 :
                    isUrl = True
                    break
            else :
                patternCount = 0
        if not isUrl :
            newTweet.append(words)
    return newTweet

# %%
def TagAndEmptyRemover(tweet) :
    newTweet = []
    for words in tweet :
        words = words.translate(str.maketrans(' ', ' ', '!\"“$%&\'()*+,-./:;<=>?[\]^_`{|}~'))
        shouldRemoved = False
        wordLength = len(words)
        if wordLength == 0 :
            shouldRemoved = True
        elif wordLength == 1 :
            if words[0] == '\n' :
                shouldRemoved = True
        else:  
            if words[0] == '@' or words[0] == '#':
                shouldRemoved = True
        if not shouldRemoved :
            newTweet.append(words)
    return newTweet

# %%
def toLower(tweet) :
    lowerDict = {
        'A' : 'a', 'B' : 'b', 'C' : 'c', 'Ç' : 'ç', 'D' : 'd', 'E' : 'e', 'F' : 'f',
        'G' : 'g', 'Ğ' : 'ğ', 'H' : 'h', 'I' : 'ı', 'İ' : 'i', 'J' : 'j', 'K' : 'k',
        'L' : 'l', 'M' : 'm', 'N' : 'n', 'O' : 'o', 'Ö' : 'ö', 'P' : 'p', 'Q' : 'q',
        'R' : 'r', 'S' : 's', 'Ş' : 'ş', 'T' : 't', 'U' : 'u', 'Ü' : 'ü', 'V' : 'v',
        'W' : 'w', 'X' : 'x', 'Y' : 'y', 'Z' : 'z'
    }
    nTweet = []
    for word in tweet :
        nWord = ''
        for letter in word :
            if letter in lowerDict.keys() :
                letter = lowerDict.get(letter)
            nWord += letter
        nTweet.append(nWord)
    return nTweet

# %%
def replace_emoticon(tweet):
    new_tweet = []
    for word in tweet:
        check_pos = re.findall(r'(?::\)|:-\)|=\)|:D|:d|<3|\(:|:\'\)|\^\^|;\)|\(-:)|😀|😇|🤣|❤️|🧡|💛|💚|💙|💜|🖤|🤍|🤎|😍|😘|😛|🤪|👍', word)
        check_neg = re.findall(r'(:-\(|:\(|;\(|;-\(|=\(|:/|:\\|-_-|\):|\)-:)|😒|😞|😔|😟|😕|🙁|🥺|😢|😡|🤬|👎|💔', word)
        if check_pos:
            word = "xgülücük"
        elif check_neg:
            word = "xüzülcük"
        new_tweet.append(word)
    return new_tweet

# %%
def remove_repeating_char(tweet):
    new_tweet = []
    for word in tweet:
        new_word = ""
        prev_char = ''
        for char in word:
            if prev_char == char:
                continue
            new_word = new_word + char
            prev_char = char
        new_tweet.append(new_word)
    return new_tweet

# %%
def foo_zar(x):
    return x.split()[0]

# %%
predict = pd.read_csv('Desktop/predict.csv', lineterminator = '\n')
fit = pd.read_csv('Desktop/fit.csv', lineterminator = '\n')

# %%
df = pd.read_csv('df2.csv', lineterminator = '\n')

# %%
df
# Out:
#                                                    Tweets        Time  \
# 0                 Üniversite hayatını yaşayamıyoruz ki aq  2020-12-01
# 1                                   Cezasız kalmaz umarım  2020-12-01
# 2                                               Annem bee  2020-12-01
# 3         Yanlış.. 2010 facebook paylaşımlarımdan bir ...  2020-12-01
# 4          Hafif insanlara ağır geldik olay bundan ibaret  2020-12-01
# ...                                                   ...         ...
# 920799                              Zorbalıkta sınır yok.  2020-10-26
# 920800    Boykot konusunda gerçeği Babacan söyledi ve ...  2020-10-26
# 920801            MÜSİAD’da da liyakat her yerde liyakat.  2020-10-26
# 920802   @recepgurkan ayıp etmiş. Beklemezdim. Bana ar...  2020-10-26
# 920803    Bir martıyla yaz gelmez. İstisnalar kaideyi ...  2020-10-26
#
#                                               BeforeLemma  \
# 0                üniversite hayatını yaşayamıyoruz ki aq
# ...

# %%
tweets = df.Tweets

# %%
tweets = predict.Tweets

# %%
tweets = fit.Tweets

# %%
newTweetSet = []
for tweet in tweets :
    text = tweet.split()
    text = UrlRemover(text)
    text = replace_emoticon(text)
    text = TagAndEmptyRemover(text)
    text = toLower(text)
    text = remove_repeating_char(text)
    
    newTweet = ''
    for words in text :
        newTweet += words + ' '  
    newTweetSet.append(newTweet)

# %%
predict["Tweets"] = newTweetSet
del predict["Unnamed: 0"]
predict.Tweets.to_csv("predict.csv", index = False)

# %%
fit["Tweets"] = newTweetSet
del fit["Unnamed: 0"]
fit.Tweets.to_csv("fit.csv", index = False)

# %%
predict.to_csv("predict.csv", index = False)
fit.to_csv("fit.csv", index = False)

# %%
df["BeforeLemma"] = newTweetSet

# %%
df["BeforeLemma"].to_csv("df.txt", index = False)

# %%
index = df.BeforeLemma.drop_duplicates(keep='first').index
df = df.loc[index]
df = df.reset_index()
del df["index"]

# %%
df.to_csv("df.txt", index = False)

# %%
df_Lem = pd.read_csv('Desktop/df.txt', names = ["Lemma"], skip_blank_lines=False)
df["Lemma"] = df_Lem

# %%
df.to_csv("df3.csv", index = False)

# %%
df_Lab = pd.read_csv('new_Predicted_2.csv')

# %%
df.Labels = df_Lab.Labels

# %%
df = df.join(df_Lab)

# %%
df
# Out:
#                                                    Tweets        Time  \
# 0                 Üniversite hayatını yaşayamıyoruz ki aq  2020-12-01
# 1                                   Cezasız kalmaz umarım  2020-12-01
# 2                                               Annem bee  2020-12-01
# 3         Yanlış.. 2010 facebook paylaşımlarımdan bir ...  2020-12-01
# 4          Hafif insanlara ağır geldik olay bundan ibaret  2020-12-01
# ...                                                   ...         ...
# 920799                              Zorbalıkta sınır yok.  2020-10-26
# 920800    Boykot konusunda gerçeği Babacan söyledi ve ...  2020-10-26
# 920801            MÜSİAD’da da liyakat her yerde liyakat.  2020-10-26
# 920802   @recepgurkan ayıp etmiş. Beklemezdim. Bana ar...  2020-10-26
# 920803    Bir martıyla yaz gelmez. İstisnalar kaideyi ...  2020-10-26
#
#                                               BeforeLemma  \
# 0                üniversite hayatını yaşayamıyoruz ki aq
# ...

# %%
df.to_csv("df2.csv", index = False)

# %%
df["Time"] = df.Time.apply(foo_zar)

# %%
df.columns = ['Tweets', 'Time', 'BeforeLemma', 'Lemma', 'Labels']

# %%
df
# Out:
#                                                    Tweets        Time  \
# 0       bıraktım dümeni  bu dalgalar atacak uzaklara beni  2021-01-12
# 1       Gün geçtikçe tükeniyor birer birer yaşama sebe...  2021-01-12
# 2             Canımı sokakta buldum ve geri bıraktım orda  2021-01-12
# 3       Bir bilsen ağlamak çare de değil kiÖlücem mi k...  2021-01-12
# 4       Twitter web de neden otomatik tweet özelliği v...  2021-01-10
# ...                                                   ...         ...
# 800249  Son 48 saatten beri salgının dünyadaki artış h...  2020-03-30
# 800250  İmamoğlu patladı umutlarını Mansur Yavaş’a taş...  2020-03-30
# 800251  İBB Türkiyenin 3-4 hafta gerisinde. Ülkemiz sa...  2020-03-30
# 800252  Batılılar insan kurtarmaya değil insan öldürme...  2020-03-30
# 800253  Ekrem İmamoğlu ve ekibi kontrolü kaybettikçe t...  2020-03-30
#
#                                               BeforeLemma  \
# 0       bıraktım dümeni bu dalgalar atacak uzaklara beni
# ...
